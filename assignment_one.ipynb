# %% [markdown]
# <a href="https://colab.research.google.com/github/sidhdeshwari/assignments/blob/main/assignment_one.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def register():
  file=open("database.txt","r")
  username=input("please enter username:")
  email=input("please enter email:")
  valid_email(email)
  password=input("please enter password:")
  valid_password(password)
  password1=input("confirm password:")
  d=[]
  f=[]
  for i in file:
    a,b=i.split(",")
    b=b.strip()
    d.append(a)
    f.append(b)
  data=dict(zip(d,f))

  if password!=password1:
    print("Sorry password don't match, restart")
    register()
  else:
    if len(password)<=5:
     print("Oops password is to short, restart")
     register()
    #elif username in d:
     #print("username exists")
      #register()
    else:
      file=open("database.txt","a")
      file.write(username+","+password+"\n")
      print("success!!")


def access():
  file=open("database.txt","r")
  username=input("enter username:")
  password=input("enter password:")

  if not len(username or password)<1:
    d=[]
    f=[]
    for i in file:
      a,b=i.split(",")
      #b=b.strip()
      d.append(a)
      f.append(b)
    data=dict(zip(d,f))

  try:
   if password==data[username]:
      print("login successfully")
      print("hi", username)
   else :
      print("password or username incorrect")
  except:
       print("incorrect password or username")

def get_pass():
  file=open("database.txt","r")
  user=input("To access your forgoteen password,please enter your user name")
  users=[]
  passwords=[]
  for i in file:
    a,b=i.split(",")
    b=b.strip()
    users.append(a)
    passwords.append(b)
  info=dict(zip(users,passwords))

  if user in info:
    print("here is your password: ", info.get(user))
  else:
    print("user does not exist")
    print("you have to register")
    home()

def valid_email(email):
  if '@' not in email:
    print("please enter valid email")
    email=input("enter email:")
    ind=email.index("@")

    if '.' not in email:
      print("please enter valid email")
      email=input("enter email:")
      valid_email(email)

    
      if '.com' not in email[ind:] or '@.' in email:
         print("please enter a valid email")
         email=input("enter email:")
         valid_email(email)

def valid_password(pwd):
  symbols={'~',':',"'",'[','\\','@','^','{','%','(','-','"','*','|',',','&','<','`','}','.','_','=',']','!','>','>',';','?','#','$',')','/'}
  val=True

  if len(pwd)<5:
    print("length should be atleast 5 character")
    val=False
    password=input("enter password:")
    valid_password(password)

  elif len(pwd)>16:
    print("length should not greater then 16 character")
    val=False
    password=input("enter password:")
    valid_password(password)
  
  elif not any(char.isdigit() for char in pwd):
    print("password should have atleast one digit")
    val=False
    password=("enter password:")
    valid_password(password)

  elif not any(char.isupper() for char in pwd):
    print("password should have atleat one uppercase character")
    val=False
    password=input("enter password:")
    valid_password(password)

  elif not any(char.islower() for char in pwd):
    print("password should have atleast one lowercase character")
    val=False
    password=("enter password:")
    valid_password(password)
  
  elif not any(char in symbols for char in pwd):
    print("password should have atleast one special character")
    val=False
    password=input("enter password:")
    valid_password(password)
  
  elif val:
    return val



def home():
  option=input("login | signup | retrive_password")
  if option=="login":
    access()
  elif option=="signup":
    register()
  elif option=="retrive_password":
    get_pass()
  else:
    print("enter an option:")
home()
# Out:
# login | signup | retrive_passwordretrive_password
# To access your forgoteen password,please enter your user namerohan
# here is your password:  @143Rohan
